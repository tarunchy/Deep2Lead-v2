# %% [markdown]
# ## Big Data For Health - Fall 2020 - Projest Group 6

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# tensorflow backend
from os import environ
environ['KERAS_BACKEND'] = 'tensorflow'
# import scientific py
import numpy as np
import pandas as pd
# rdkit stuff
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import PandasTools
# plotting stuff
import matplotlib.pyplot as plt
import matplotlib as mpl
from IPython.display import SVG, display
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
# adding path with code to PATH variable
import sys
sys.path.insert(1, '/Users/user/Documents/BD4H/drug_discovery/2_new_molecule_generation/src')
# vae stuff
from processor.vae_utils import VAEUtils
from processor import mol_utils as mu
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Using the Variational Auto Encoder

# %% [markdown]
# smiles <i class="fa fa-arrow-right" aria-hidden="true"></i> x <i class="fa fa-arrow-right" aria-hidden="true"></i> z <i class="fa fa-arrow-right" aria-hidden="true"></i> x_r <i class="fa fa-arrow-right" aria-hidden="true"></i> smiles_r

# %%
# creating the variational autoencoder and loading the pretrained model
#sys.path.insert(2, '/Users/user/Documents/BD4H/drug_discovery/2_new_molecule_generation/model/pre-train/with_property')
print('Loading Pre-Trained Model...')
vae = VAEUtils(directory='./model/pre-train/with_property')
print('Model Loaded successfully..')
# Out:
# Loading Pre-Trained Model...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-430cec9109eb> in <module>
#       2 #sys.path.insert(2, '/Users/user/Documents/BD4H/drug_discovery/2_new_molecule_generation/model/pre-train/with_property')
#       3 print('Loading Pre-Trained Model...')
# ----> 4 vae = VAEUtils(directory='./model/pre-train/with_property')
#       5 print('Model Loaded successfully..')
#
# ~/Documents/BD4H/drug_discovery/2_new_molecule_generation/src/processor/vae_utils.py in __init__(self, exp_file, encoder_file, decoder_file, directory)
#      28             self.params["decoder_weights_file"] = decoder_file
#      29         # char stuff
# ---> 30         chars = yaml.safe_load(open(self.params['char_file']))
#      31         self.chars = chars
#      32         self.params['NCHARS'] = len(chars)
#
# ...

# %%
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
import pickle

import math
from collections import defaultdict

import os.path as op



def numBridgeheadsAndSpiro(mol, ri=None):
    nSpiro = rdMolDescriptors.CalcNumSpiroAtoms(mol)
    nBridgehead = rdMolDescriptors.CalcNumBridgeheadAtoms(mol)
    return nBridgehead, nSpiro


def calculateScore(m):
   
    # fragment score
    fp = rdMolDescriptors.GetMorganFingerprint(m,
                                               2)  # <- 2 is the *radius* of the circular fingerprint
    fps = fp.GetNonzeroElements()
    score1 = 0.
    nf = 0
    for bitId, v in fps.items():
        nf += v
        sfp = bitId
        score1 += v
    score1 /= nf

    # features score
    nAtoms = m.GetNumAtoms()
    nChiralCenters = len(Chem.FindMolChiralCenters(m, includeUnassigned=True))
    ri = m.GetRingInfo()
    nBridgeheads, nSpiro = numBridgeheadsAndSpiro(m, ri)
    nMacrocycles = 0
    for x in ri.AtomRings():
        if len(x) > 8:
            nMacrocycles += 1

    sizePenalty = nAtoms**1.005 - nAtoms
    stereoPenalty = math.log10(nChiralCenters + 1)
    spiroPenalty = math.log10(nSpiro + 1)
    bridgePenalty = math.log10(nBridgeheads + 1)
    macrocyclePenalty = 0.
    # ---------------------------------------
    # This differs from the paper, which defines:
    #  macrocyclePenalty = math.log10(nMacrocycles+1)
    # This form generates better results when 2 or more macrocycles are present
    if nMacrocycles > 0:
        macrocyclePenalty = math.log10(2)

    score2 = 0. - sizePenalty - stereoPenalty - spiroPenalty - bridgePenalty - macrocyclePenalty

    # correction for the fingerprint density
    # not in the original publication, added in version 1.1
    # to make highly symmetrical molecules easier to synthetise
    score3 = 0.
    if nAtoms > len(fps):
        score3 = math.log(float(nAtoms) / len(fps)) * .5

    sascore = score1 + score2 + score3

    # need to transform "raw" value into scale between 1 and 10
    min = -4.0
    max = 2.5
    sascore = 11. - (sascore - min + 1) / (max - min) * 9.
    # smooth the 10-end
    if sascore > 8.:
        sascore = 8. + math.log(sascore + 1. - 9.)
    if sascore > 10.:
        sascore = 10.0
    elif sascore < 1.:
        sascore = 1.0

    return sascore


def processMols(mols):
    print('smiles\tName\tsa_score')
    for i, m in enumerate(mols):
        if m is None:
            continue

        s = calculateScore(m)

        smiles = Chem.MolToSmiles(m)
        print(smiles + "\t" + m.GetProp('_Name') + "\t%3f" % s)

# %%
import os
from rdkit.Chem import rdBase, RDConfig
from rdkit import Chem
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem.Descriptors import qed 
from rdkit.Chem import Descriptors

print( rdBase.rdkitVersion )
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import SimilarityMaps
size = (120, 120)


smiles_1 = mu.canon_smiles('C1CNP(=O)(OC1)N(CCCl)CCCl')

mol = Chem.MolFromSmiles(smiles_1)
fig = Draw.MolToMPL(mol, size=size)


#AllChem.Compute2DCoords(mol)
#AllChem.GenerateDepictionMatching3DStructure(mol,mol)
qed1 = qed( mol)
print (qed1)

print(Descriptors.MolLogP(mol))


print(calculateScore(mol))

AllChem.ComputeGasteigerCharges(mol)
contribs = [mol.GetAtomWithIdx(i).GetDoubleProp('_GasteigerCharge') for i in range(mol.GetNumAtoms())]
fig = SimilarityMaps.GetSimilarityMapFromWeights(mol, contribs, colorMap='jet', contourLines=10)
# Out:
# 2020.09.1
# 0.6057206690801091
# 1.884
# 3.3665990412268814

# %%
df = pd.read_csv('/Users/user/Documents/BD4H/group_project/ref1/group_project_team6/chemical_vae/models/top_100_smiles.csv')

for idx, row in df.iterrows():
    #print( len(row['smiles']))
    tempMol = Chem.MolFromSmiles(row['smiles'])
    df.loc[idx,'logP'] = Descriptors.MolLogP(tempMol)
    df.loc[idx,'qed'] = qed(tempMol)
    df.loc[idx,'SAS'] = calculateScore(tempMol)
    
#df.to_csv('./chemical_vae/models/top_100_smiles_model.csv',index=False)
df
# Out:
#                                            smiles    logP       qed       SAS
# 0         O=S(=O)(NC[C@@H](O)CN1CCOCC1)NCC(F)(F)F -1.3342  0.540231  3.527034
# 1          O=S(=O)(NC[C@H](O)CN1CCOCC1)NCC(F)(F)F -1.3342  0.540231  3.527034
# 2              O=C(c1ccn2nnnc2c1)N(CCO)CCN1CCOCC1 -1.1090  0.720823  3.195509
# 3              O=C(c1ccc2nnnn2c1)N(CCO)CCN1CCOCC1 -1.1090  0.720823  3.195509
# 4      Cn1ccn2ncc(C(=O)N3CCN(CCO)C[C@@H](O)C3)c12 -1.2162  0.742549  3.583565
# ..                                            ...     ...       ...       ...
# 95          CN(C)c1nc(N)nc(C(=O)N(C)CCN2CCOCC2)n1 -1.0760  0.733167  3.166754
# 96   CC1(O)CN(C(=O)[C@H]2CC(=O)N(CCN3CCOCC3)C2)C1 -1.2397  0.703017  3.583565
# 97  CC1(O)CN(C(=O)[C@@H]2CC(=O)N(CCN3CCOCC3)C2)C1 -1.2397  0.703017  3.583565
# 98         COC(=O)CN(CCN1CCOCC1)C(=O)C1=NNC(=O)C1 -1.8039  0.580652  3.166754
# 99      O=C(CN1CCOCC1)N1CCN(C(=O)C2=NNC(=O)C2)CC1 -2.1347  0.639897  3.195509
#
# [100 rows x 4 columns]

# %%
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import Draw

# remove warnings and errors from notebook (lots of them due non valid molecule generation)
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

smiles_1 = 'C1CNP(=O)(OC1)N(CCCl)CCCl'

X_1 = vae.smiles_to_hot(smiles_1,canonize_smiles=False)
smiles_1_latent = vae.encode(X_1)
smiles_1_latent
print('{:20s} : {} with norm {:.3f}'.format('latent representation',smiles_1_latent.shape, np.linalg.norm(smiles_1_latent)))

LATENT_DIM = 196
z_1 = vae.encode(X_1,LATENT_DIM)
z_random = np.random.normal(size=(1,196))
print('{:20s} : {} with norm {:.3f}'.format('Random Latent representation',z_random.shape, np.linalg.norm(z_random)))
print(z_1.shape)
print(type(z_1))

print(z_1)

print('Random Smile',type(z_random))



print(z_random)

z_1 = z_random
# Out:
# latent representation : (1, 196) with norm 12.660
# Random Latent representation : (1, 196) with norm 13.463
# (1, 196)
# <class 'numpy.ndarray'>
# [[ 0.09737276  0.90729671  0.22117444  1.29038827 -0.68652671  0.52751719
#    0.42937668 -0.80199529  0.5500198   0.03372453 -0.34402645 -1.12835916
#    0.20543956 -2.42182848 -0.62426928 -0.1902575   0.0756035  -0.81057847
#   -0.18144412 -0.21930336 -0.3095627   1.44243279 -0.55489056  0.94207525
#   -0.03631925 -1.24283328 -0.47242483 -1.58701118  0.30752252  0.36002428
#   -1.40470393  0.55438907  0.28021933  0.2146986   0.55088777  0.36767526
#    0.66936776 -0.67374868 -0.90008414 -0.43962514  0.58010423  0.68304956
#    1.06421666  0.16911768  0.47627605  1.79073027 -0.78993909  0.63322439
#    0.09305631  1.54771088  0.29895897  1.56279278  0.2666835  -0.59960107
#   -1.2436554   0.48651656  1.10700847  0.9608144  -1.34822206 -0.77340929
#    0.83175171  0.73311113 -0.75387852 -0.5444633   0.75380928  0.43247324
# ...

# %%
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import Draw

# remove warnings and errors from notebook (lots of them due non valid molecule generation)
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

import sys
sys.stdout.flush()

i = 1
iteration = 1000000
checkPoint = 11111

print('Generating %s new molecules from random space..'%str(iteration))

#working_mols_list =  []
#generated_mols_list = []

file_path = '/Users/user/Documents/BD4H/group_project/ref1/group_project_team6/chemical_vae/models/random/'
working_mols_file = open(file_path + 'from_set_'+ str(iteration) + '_working_smiles_model.csv','w')
generated_mols_file = open(file_path + 'from_set_'+ str(iteration) + '_random_smiles_model.csv','w')


while i <= iteration:
    lm = np.random.normal(size=(1,196))
    temp1 = vae.decode(lm)
    reconstructed_smiles_1 = vae.hot_to_smiles(temp1,strip=True)[0]
    generated_mols_file.write("%s\n" % reconstructed_smiles_1)
    try:
        #generated_mols_list.append(reconstructed_smiles_1)
        mol = Chem.MolFromSmiles(reconstructed_smiles_1)
        if mol:
            working_mols_file.write("%s\n" % reconstructed_smiles_1)
    except:
        i += 1
        continue
        
    if i%checkPoint == 0 :
        print('Number of iteration completed',str(i))
    i += 1
    
#print('Number of molecule generated:',len(generated_mols_list))
#working_mols_df = pd.DataFrame(working_mols_list, columns=['smiles'])
      
#generated_mols_df = pd.DataFrame(generated_mols_list, columns=['smiles'])

generated_mols_file.close()
working_mols_file.close()
      
#working_mols_df.to_csv(working_mols_file,index=False)

#generated_mols_df.to_csv(generated_mols_file,index=False)

#Draw.MolsToGridImage([mol for mol in working_mols], molsPerRow=1)

print('%s new molecules from random space is complete'% str(iteration))
# Out:
# Generating 1000000 new molecules from random space..
# Number of iteration completed 11111
# Number of iteration completed 22222
# Number of iteration completed 33333
# Number of iteration completed 44444
# Number of iteration completed 55555
# Number of iteration completed 66666
# Number of iteration completed 77777
# Number of iteration completed 88888
# Number of iteration completed 99999

# %%
def z_to_smiles(self,
                    z,
                    decode_attempts=250,
                    noise_norm=0.0,
                    constant_norm=False,
                    early_stop=None):
        if not (early_stop is None):
            Z = np.tile(z, (25, 1))
            Z = self.perturb_z(Z, noise_norm, constant_norm)
            X = self.decode(Z)
            smiles = self.hot_to_smiles(X, strip=True)
            df = self.prep_mol_df(smiles, z)
            if len(df) > 0:
                low_dist = df.iloc[0]['distance']
                if low_dist < early_stop:
                    return df

        Z = np.tile(z, (decode_attempts, 1))
        Z = self.perturb_z(Z, noise_norm)
        X = self.decode(Z)
        smiles = self.hot_to_smiles(X, strip=True)
        #df = self.prep_mol_df(smiles, z)
        df = pd.DataFrame({'smiles': smiles})
        #print(df.head(5))
        return df

# %%
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from IPython.display import SVG, display

# remove warnings and errors from notebook (lots of them due non valid molecule generation)
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

import sys
sys.stdout.flush()

i = 1
iteration = 10
checkPoint = 111
stdev = 0.01
noise=11.0

print('Generating %s new molecules from high activity space..'%str(iteration))

#working_mols_list =  []
#generated_mols_list = []

file_path = './chemical_vae/models/random/'
#working_mols_file = open(file_path + 'from_100set_'+ str(iteration) + '_working_smiles_model.csv','w')
#generated_mols_file = open(file_path + 'from_100set_'+ str(iteration) + '_random_smiles_model.csv','w')

df_results = pd.DataFrame()

for idx, row in df.iterrows():
    if idx%10 == 0 :
        print('Number of iteration completed',str(idx))
    X_1 = vae.smiles_to_hot(row['smiles'],canonize_smiles=False)
    #smiles_1_latent = vae.encode(X_1)
    z_1 = vae.encode(X_1,LATENT_DIM)
    df_results = z_to_smiles(vae,z_1,decode_attempts=100,noise_norm=noise)
    #df_results = df_results.drop_duplicates()
    df_results.to_csv(file_path + 'from_100set_'+ str(iteration) + '_random_smiles_model1.csv',mode='a',header=False,index=False)
    
print('Complete')
#df_results = df_results.reset_index(drop=True)
#df_results = df_results.drop_duplicates()

#df_results

#display(PandasTools.FrameToGridImage(df_results,column='mol', legendsCol='smiles',molsPerRow=5))
# Out:
# Generating 10 new molecules from high activity space..
# Number of iteration completed 0
# Number of iteration completed 10
# Number of iteration completed 20
# Number of iteration completed 30
# Number of iteration completed 40
# Number of iteration completed 50
# Number of iteration completed 60
# Number of iteration completed 70
# Number of iteration completed 80
# Number of iteration completed 90
# Complete

# %%
from rdkit import Chem
from rdkit import RDLogger
from rdkit.Chem import Draw

# remove warnings and errors from notebook (lots of them due non valid molecule generation)
lg = RDLogger.logger()
lg.setLevel(RDLogger.CRITICAL)

import sys
sys.stdout.flush()

i = 1
iteration = 10
checkPoint = 111
stdev = 5.0

print('Generating %s new molecules from high activity space..'%str(iteration))

#working_mols_list =  []
#generated_mols_list = []

file_path = './chemical_vae/models/random/'
working_mols_file = open(file_path + 'from_100set_'+ str(iteration) + '_working_smiles_model.csv','w')
generated_mols_file = open(file_path + 'from_100set_'+ str(iteration) + '_random_smiles_model.csv','w')


for idx, row in df.iterrows():
    i=0
    print(idx)
    X_1 = vae.smiles_to_hot(row['smiles'],canonize_smiles=False)
    smiles_1_latent = vae.encode(X_1)
    z_1 = vae.encode(X_1,LATENT_DIM)
    while i <= iteration:
        i += 1
        rand_val = stdev * np.random.randn(1, LATENT_DIM)
        lm = rand_val + z_1
        temp1 = vae.decode(lm)
        reconstructed_smiles_1 = vae.hot_to_smiles(temp1,strip=True)[0]
        print(reconstructed_smiles_1)
        generated_mols_file.write("%s\n" % reconstructed_smiles_1)
       
generated_mols_file.close()
working_mols_file.close()
print('Complete!!')

print('%s new molecules from 100 High activity space is complete'% str(iteration))
# Out:
# Generating 10 new molecules from high activity space..
# 0
# ClC(C@n2)c(NC3C(C[NH+]c3)C3C2)C1C1C(C2)[C@@]3(C(=C3)C2)C2C
# O=S(=O)=O)(=C)C(O[C@@](F)(Cl)c1ccn2c1ccc(O)c(N(O)N)[C@H]cc2)ccccc2
# C/C(=[N+](C@](C(N(c\cccc(C)oc3)nn(C)c\ccsc1=O)/N\N-]1c1ccccc1
# C#COC(=O)c1C)o1=C1C1=C(C)(C1=O2ncc1)C2=C2=C(=C1=C(=Ncc2=C)=C2=C(C(C2=C(=Nc2=C)=C2=C(C#NH]2=N=Nc2=C2=C1C1C(C2=C1=N=N\C)=C
# OCC(O)[NH+](C)C)C(Br)OC[C@H]2CC(O)([NH+]4C@@C(C)OC@@H]3)[C@H]1Cl
# ONC(=O)C[@@H](O)N(C)=OC(N)C(=O)ccc(F)oc2c3cccc2)c2ccc3(cc2)cc2cccc2
# Cc1c(N/C([NH+](=/C2CC[C@@H]2=O)C[C@@@](=O)C@@H](O)(C)C(C)S(C)(C)C(C)C)(C(C)nc(c1Cl
# CN(C)c1nnc(CC(C)C@@H](=O)(NC)Nc1ccc(=O)n2)cn1-c1cccc1-ccccc1
# O=C(/N)=O)(=O)/N/N=C(C2nnc2cccc3n1)N/C(/C([\[O-])=O)C/C(OC(C(C(C(C)/O)O)O)(=O)[O)[C)\O)c(C@H](=O)o/C(=O)N=O)/C)/C(O)[NH]
# Cn1C(=O)nc(N(C(N2CCOC(C(C@@H]3)CCCOC[C@H]3C)c2)ccccc2)c2)C1
# c1cc2nnnc(NC(=O)c4c(-nc4nccnc5c4nc3n3nncnncncnncncnncnnncnnncnncnnc3nn3ncncnnnncncnnc4ncnnnncnnnnncncncncncnn/cnncnnncnn
# 1
# ...
